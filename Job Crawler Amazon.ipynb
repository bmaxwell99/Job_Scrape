# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# Replace "/path/to/msedgedriver" with the path to the Microsoft Edge WebDriver executable file on your computer
driver = webdriver.Edge(executable_path="/path/to/msedgedriver")

url = "https://www.amazon.jobs/en/search?offset=0&result_limit=10&sort=relevant&job_type%5B%5D=Full-Time&country%5B%5D=USA&state%5B%5D=Washington&state%5B%5D=New%20York&distanceType=Mi&radius=24km&is_manager%5B%5D=0&latitude=&longitude=&loc_group_id=&loc_query=&base_query=Solution%20Architect&city=&country=&region=&county=&query_options=&"


# Navigate to the webpage that contains the <span> elements
driver.get(url)

# Find the first <span> element with class "job-count"
job_count_span = driver.find_element(By.CSS_SELECTOR, "span.job-count")

# Get the child containers of the <span> element
child_containers = job_count_span.find_elements(By.XPATH, "./*")

# Loop through the child containers and print their text
container.text

# Close the browser window
driver.quit()
# Out:
# C:\Users\dark_\AppData\Local\Temp\ipykernel_40044\2397741931.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path="/path/to/msedgedriver")
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
# ...

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# create a new Chrome driver object
driver = webdriver.Chrome()

# navigate to LinkedIn and login
driver.get('https://www.linkedin.com/')
# TODO: add code to login to LinkedIn

# navigate to the Jobs page on LinkedIn
driver.get('https://www.linkedin.com/jobs/')

# search for job postings using a keyword and location
search_keyword = 'data scientist'
search_location = 'United States'
search_input = driver.find_element(By.CLASS_NAME, 'search-global-typeahead__input')
search_input.send_keys(search_keyword)
location_input = driver.find_element(By.CSS_SELECTOR, 'input[aria-label="Location, skill, or company"]')
location_input.send_keys(search_location)
location_input.send_keys(Keys.RETURN)

# wait for the search results to load
time.sleep(5)

# scrape the job postings on the search results page
job_postings = driver.find_elements(By.CSS_SELECTOR, 'li[data-test-job-info]')
for posting in job_postings:
    # extract information about each job posting
    title = posting.find_element(By.TAG_NAME, 'h3').text
    company = posting.find_element(By.TAG_NAME, 'h4').text
    location = posting.find_element(By.CSS_SELECTOR, 'span.job-result-card__location').text
    date_posted = posting.find_element(By.TAG_NAME, 'time').get_attribute('datetime')
    job_url = posting.find_element(By.TAG_NAME, 'a').get_attribute('href')
    
    # TODO: add code to store or process the job posting information

# close the Chrome driver
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40044\3830034440.py in <module>
#      17 search_keyword = 'data scientist'
#      18 search_location = 'United States'
# ---> 19 search_input = driver.find_element(By.CLASS_NAME, 'search-global-typeahead__input')
#      20 search_input.send_keys(search_keyword)
#      21 location_input = driver.find_element(By.CSS_SELECTOR, 'input[aria-label="Location, skill, or company"]')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     829             value = f'[name="{value}"]'
#     830
# --> 831         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     832
#     833     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ...

# %%
base_url = "https://www.amazon.jobs/en/search?offset=0&result_limit=10&sort=relevant&job_type%5B%5D=Full-Time&country%5B%5D=USA&state%5B%5D=Washington&state%5B%5D=New%20York&distanceType=Mi&radius=24km&is_manager%5B%5D=0&latitude=&longitude=&loc_group_id=&loc_query=&base_query="
query = "Solution%20Architect"
end_url = "&city=&country=&region=&county=&query_options=&"
base_url + query + end_url
# Out:
# 'https://www.amazon.jobs/en/search?offset=0&result_limit=10&sort=relevant&job_type%5B%5D=Full-Time&country%5B%5D=USA&state%5B%5D=Washington&state%5B%5D=New%20York&distanceType=Mi&radius=24km&is_manager%5B%5D=0&latitude=&longitude=&loc_group_id=&loc_query=&base_query=Solution%20Architect&city=&country=&region=&county=&query_options=&'
